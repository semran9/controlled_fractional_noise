# %%
import os
import sys


sys.path.append("..")

import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import torch
import torchsde
from fractional_neural_sde.fractional_noise import SparseGPNoise
from fractional_neural_sde.latent_sde import LatentSDE
from fractional_neural_sde.utils import LinearScheduler, manual_seed, plot_setting
from torch import distributions, optim

plot_setting(font_size=20)
import matplotlib as mpl
mpl.rcParams.update(mpl.rcParamsDefault) #plots do not work without this

# %%
class TrueNoise(SparseGPNoise):
    def compute_hurst(self, t, ys):
        t = t.view(-1, 1)
        return torch.ones(1, 1) * torch.sigmoid((1.0 - t) * 7.0) * 0.5 + 0.3


def get_data():

    t0, t1 = 0.0, 2.0
    batch_size = 200

    x0 = 1.0
    alpha = 0.5
    beta = 0.5
    true_wn = TrueNoise(t0=t0, t1=t1, dt=1e-2, num_steps=500, num_inducings=50)

    true_wn.precompute(batch_size=batch_size)

    ts, B_h, _ = true_wn.sample_alternative(batch_size)

    ht = torch.stack(
        [true_wn.compute_hurst(t, x0) for t in ts], dim=0
    )  # t_size, 1, state_size

    # the exact solution
    X_t = x0 * torch.exp(
        beta * B_h
        + alpha * ts.reshape(-1, 1, 1)
        - 0.5 * beta**2 * ts.reshape(-1, 1, 1) ** (2 * ht)
    )
    X_t = X_t.squeeze().transpose(0, 1)

    # shift time a bit
    shift = 0.1
    start = ts[0].reshape((1,))
    end = ts[-1].reshape((1,)) + shift
    ts = ts + shift
    ts_ext = torch.cat([start, ts, end], dim=0)

    return ts, ts_ext, X_t[1], ht

# %%
def plot(
    sample_fn, ts, ys, ts_vis, batch_size, sdeint_fn, eps, bm, method, dt, prior=True
):

    palette = sns.color_palette("Blues_r")

    fill_color = palette[2]
    mean_color = palette[0]

    alphas = [0.05, 0.10, 0.15, 0.20, 0.25, 0.30, 0.35, 0.40, 0.45, 0.50, 0.55]
    percentiles = [0.999, 0.99, 0.9, 0.8, 0.7, 0.6, 0.5, 0.4, 0.3, 0.2, 0.1]

    with torch.no_grad():
        zs = sample_fn(
            ts=ts_vis,
            batch_size=batch_size,
            sdeint_fn=sdeint_fn,
            method=method,
            dt=dt,
            bm=bm,
            eps=eps,
        )
        zs = zs.squeeze()
        ts_vis_, zs_ = ts_vis.cpu().numpy(), zs.cpu().numpy()
        zs_ = np.sort(zs_, axis=1)

        plt.subplots(figsize=(8, 4), frameon=False)

        for alpha, percentile in zip(alphas, percentiles):
            idx = int((1 - percentile) / 2.0 * batch_size)
            zs_bot_, zs_top_ = zs_[:, idx], zs_[:, -idx]
            plt.fill_between(ts_vis_, zs_bot_, zs_top_, alpha=alpha, color=fill_color)

        if not prior:
            # plot mean
            plt.plot(
                ts_vis_,
                zs_.mean(axis=1),
                color=mean_color,
                linestyle="--",
                linewidth=2.5,
            )

        # plot data
        if ys.ndim == 2:
            plt.scatter(ts, ys[:, 0], marker="x", zorder=3, color="k", s=50)
        else:
            plt.scatter(ts, ys, marker="x", zorder=3, color="k", s=50)

        plt.xlabel("$t$")
        plt.ylabel("$X_t$")
        plt.tight_layout()


def plot_posterior(
    sample_fn, ts, ys, ts_vis, batch_size, sdeint_fn, eps, bm, method, dt
):
    plot(
        sample_fn,
        ts,
        ys,
        ts_vis,
        batch_size,
        sdeint_fn,
        eps,
        bm,
        method,
        dt,
        prior=False,
    )


def plot_h(hurst_fn, ts_vis, ts, true_ht, shift=0.05):
    """Plot Hurst function"""
    plt.figure(figsize=(5, 4))

    with torch.no_grad():
        ht = hurst_fn(ts_vis)
        ts_vis_, ht_ = ts_vis.cpu().numpy(), ht.cpu().numpy()

        plt.plot(ts_vis_ - shift, ht_, label="ours", alpha=0.8)
        plt.plot(ts - shift, true_ht, label="true", alpha=0.8)
        plt.xlabel(r"$t$")
        plt.ylabel(r"$h(t)$")
        plt.legend()
def plot_loss(loss, iterations):
    """Plot loss"""
    plt.figure(figsize=(5, 4))
    plt.plot(iterations, loss, label="ours", alpha=0.8)
    plt.xlabel(r"$iteration$")
    plt.ylabel(r"$loss$")
    plt.legend()

# %%
train_dir = "./dump/"
adjoint = False
device = "cuda"
train_iters = 3000
kl_anneal_iters = 100
likelihood_cls = distributions.Laplace
scale = 0.025
method = "euler"
dt = 5 * 1e-3
batch_size = 1
seed = 0

# %%
manual_seed(seed)

device = torch.device(device if torch.cuda.is_available() else "cpu")
train_dir = os.path.join(train_dir, "synthetic")
ckpt_dir = os.path.join(train_dir, "ckpts")
os.makedirs(ckpt_dir, exist_ok=True)
ts, ts_ext, ys, ht = get_data()

ts_, ys_ = ts, ys
ht = ht.squeeze()

ts, ys = ts.to(device), ys.to(device)[:, None]

# %%
# plt.figure()
# plt.scatter(ts_, ys_, s=50)
white_noise = SparseGPNoise(
    t0=ts_ext[0], t1=ts_ext[-1], dt=dt, num_steps=200, num_inducings=50
).to(device)

model = LatentSDE(white_noise).to(device)
sdeint_fn = torchsde.sdeint_adjoint if adjoint else torchsde.sdeint
optimizer = optim.Adam(model.parameters(), lr=0.1, weight_decay=1e-5)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.999)
kl_scheduler = LinearScheduler(iters=kl_anneal_iters)

# %%
# weights = [param for param in model.net.parameters()]
# weights

# %%
optimizer.zero_grad()
zs, kl = model(
        ts=ts, batch_size=batch_size, sdeint_fn=sdeint_fn, method=method, dt=dt
    )
zs = zs.squeeze()
zs = zs[1:-1]

likelihood = likelihood_cls(loc=zs, scale=scale)
logpy = likelihood.log_prob(ys[1:-1]).sum(dim=0).mean(dim=0)

loss = -logpy + kl * kl_scheduler.val
#loss_graph.append(loss.cpu().detach().cpu().numpy())
#iter_graph.append(i)
loss.backward()
optimizer.step()
scheduler.step()
kl_scheduler.step()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[8], line 2
#       1 optimizer.zero_grad()
# ----> 2 zs, kl = model(
#       3         ts=ts, batch_size=batch_size, sdeint_fn=sdeint_fn, method=method, dt=dt
#       4     )
#       5 zs = zs.squeeze()
#       6 zs = zs[1:-1]
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Downloads/controlled_fractional_noise/fractional_neural_sde/fractional_neural_sde/../fractional_neural_sde/latent_sde.py:185, in LatentSDE.forward(self, ts, batch_size, sdeint_fn, method, dt, bm, eps)
#     183 py0 = distributions.Normal(loc=self.py0_mean, scale=self.py0_std)
#     184 logqp0 = distributions.kl_divergence(qy0, py0).sum(dim=1)
# --> 185 self.precompute_white_noise(batch_size=batch_size, ts = ts, y0 = y0)
#     187 aug_y0 = torch.cat([y0, torch.zeros(batch_size, 1).to(y0)], dim=1)
#     189 # compute cholesky and inducing sample before solving
#     190 # compute prior ode for the white noise
#     191
#     192 # solve the path from 0 -> T
#
# File ~/Downloads/controlled_fractional_noise/fractional_neural_sde/fractional_neural_sde/../fractional_neural_sde/latent_sde.py:86, in LatentSDE.precompute_white_noise(self, batch_size, ts, y0)
#      84 def precompute_white_noise(self, batch_size, ts, y0):
#      85     """Precompute Cholesky for white noise"""
# ---> 86     self.precompute_drift(y0 = y0)
#      87     self.noise_path.precompute(batch_size = batch_size, y0 = self.drift_y0,
#      88                                yt = self.drift_yt)
#
# File ~/Downloads/controlled_fractional_noise/fractional_neural_sde/fractional_neural_sde/../fractional_neural_sde/latent_sde.py:80, in LatentSDE.precompute_drift(self, y0)
#      77 def precompute_drift(self, y0):
#      78     # sample initial point
#      79     # get time series to "integrate" over
# ---> 80     drift_path = self.drift_pass(y0).reshape(-1,1)
#      81     self.drift_y0 = drift_path[0:(drift_path.shape[0]-1)]
#      82     self.drift_yt = drift_path[1:(drift_path.shape[0])]
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/Downloads/controlled_fractional_noise/fractional_neural_sde/fractional_neural_sde/../fractional_neural_sde/latent_sde.py:74, in LatentSDE.drift_pass(self, y0)
#      72     y_n = self.net(torch.tensor([torch.sin(tn), torch.cos(tn), y_n]))
#      73     #y_n = self.h(torch.tensor(tn), y_n)
# ---> 74     drift_path = torch.cat([drift_path, y_n]) # This treats this like an ODE euler method solver
#      75 return drift_path + 1e-5
#
# RuntimeError: Tensors must have same number of dimensions: got 2 and 1

# %%
[model.net(torch.tensor([1.,1.,1.])), torch.tensor(model.qy0_mean.data).reshape(1)]
# Out:
# /var/folders/2z/7q42mmyn5f18vx697sj_30p40000gn/T/ipykernel_17852/3930324562.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   [model.net(torch.tensor([1.,1.,1.])), torch.tensor(model.qy0_mean.data).reshape(1)]
# [tensor([0.], grad_fn=<ViewBackward0>), tensor([1.])]

# %%
white_noise = SparseGPNoise(
    t0=ts_ext[0], t1=ts_ext[-1], dt=dt, num_steps=200, num_inducings=50
).to(device)

model = LatentSDE(white_noise).to(device)
sdeint_fn = torchsde.sdeint_adjoint if adjoint else torchsde.sdeint
optimizer = optim.Adam(model.parameters(), lr=0.1, weight_decay=1e-5)
scheduler = optim.lr_scheduler.ExponentialLR(optimizer, gamma=0.999)
kl_scheduler = LinearScheduler(iters=kl_anneal_iters)

# for visualization
vis_batch_size = 1024
ts_vis = torch.linspace(ts_ext[0], ts_ext[-1], 300).to(device)
eps = torch.randn(vis_batch_size, 1).to(device)
bm_vis = torchsde.BrownianInterval(
    t0=ts_ext[0],
    t1=ts_ext[-1],
    size=(vis_batch_size, 1),
    device=device,
    levy_area_approximation="space-time",
)

loss_graph = []
iter_graph = []
for i in range(train_iters):
    #if i % 300 == 0:
    #    plot_posterior(
    #        model.sample_q,
    #        ts=ts_,
    #        ys=ys_,
    #        ts_vis=ts_vis,
    #        batch_size=vis_batch_size,
    #        sdeint_fn=sdeint_fn,
    #        bm=bm_vis,
    #        eps=eps,
    #        method=method,
    #        dt=dt,
    #    )
    #    plot_h(model.noise_path.compute_hurst, ts, ts_, ht)
    #    plt.show()
    #    plt.close()

    optimizer.zero_grad()
    zs, kl = model(
        ts=ts, batch_size=batch_size, sdeint_fn=sdeint_fn, method=method, dt=dt
    )
    zs = zs.squeeze()
    zs = zs[1:-1]

    likelihood = likelihood_cls(loc=zs, scale=scale)
    logpy = likelihood.log_prob(ys[1:-1]).sum(dim=0).mean(dim=0)

    loss = -logpy + kl * kl_scheduler.val
    loss_graph.append(loss.cpu().detach().cpu().numpy())
    iter_graph.append(i)
    loss.backward()
    
    
    optimizer.step()
    scheduler.step()
    kl_scheduler.step()
    if i % 500 == 0:
        print(
            f"Iter: {i} \t"
            f"logpy: {logpy.detach().cpu().numpy():.3f} \t"
            f"kl: {kl.cpu().detach().cpu().numpy():.3f} \t"
            f"loss: {loss.cpu().detach().cpu().numpy():.3f}"
        )
        plot_loss(loss_graph[i-500:i-1], iter_graph[i-500:i-1])
        mpl.pyplot.show()
# Out:
# Iter: 0 	logpy: -3417.033 	kl: 53.644 	loss: 3417.570
# ---------------------------------------------------------------------------
# _LinAlgError                              Traceback (most recent call last)
# Cell In[10], line 44
#      25 for i in range(train_iters):
#      26     #if i % 300 == 0:
#      27     #    plot_posterior(
#    (...)
#      40     #    plt.show()
#      41     #    plt.close()
#      43     optimizer.zero_grad()
# ---> 44     zs, kl = model(
#      45         ts=ts, batch_size=batch_size, sdeint_fn=sdeint_fn, method=method, dt=dt
#      46     )
#      47     zs = zs.squeeze()
#      48     zs = zs[1:-1]
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
#    1524 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1525         or _global_backward_pre_hooks or _global_backward_hooks
#    1526         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1527     return forward_call(*args, **kwargs)
#    1529 try:
#    1530     result = None
#
# File ~/Downloads/controlled_fractional_noise/fractional_neural_sde/fractional_neural_sde/../fractional_neural_sde/latent_sde.py:186, in LatentSDE.forward(self, ts, batch_size, sdeint_fn, method, dt, bm, eps)
#     184 py0 = distributions.Normal(loc=self.py0_mean, scale=self.py0_std)
#     185 logqp0 = distributions.kl_divergence(qy0, py0).sum(dim=1)
# --> 186 self.precompute_white_noise(batch_size=batch_size, ts = ts, y0 = y0)
#     188 aug_y0 = torch.cat([y0, torch.zeros(batch_size, 1).to(y0)], dim=1)
#     190 # compute cholesky and inducing sample before solving
#     191 # compute prior ode for the white noise
#     192
#     193 # solve the path from 0 -> T
#
# File ~/Downloads/controlled_fractional_noise/fractional_neural_sde/fractional_neural_sde/../fractional_neural_sde/latent_sde.py:88, in LatentSDE.precompute_white_noise(self, batch_size, ts, y0)
#      86 """Precompute Cholesky for white noise"""
#      87 self.precompute_drift(y0 = y0)
# ---> 88 self.noise_path.precompute(batch_size = batch_size, y0 = self.drift_y0,
#      89                            yt = self.drift_yt)
#
# File ~/Downloads/controlled_fractional_noise/fractional_neural_sde/fractional_neural_sde/../fractional_neural_sde/fractional_noise.py:122, in SparseGPNoise.precompute(self, y0, yt, batch_size)
#     118 Kzz = torch.matmul(
#     119     self.Kz, self.Kz.transpose(-1, -2)
#     120 )  # num_step, dim, num_inducing, num_ducing
#     121 Kzz = Kzz.sum(dim=0)  # dim, num_inducing , num_inducing
# --> 122 self.Lz = torch.linalg.cholesky(
#     123     Kzz + torch.eye(self.num_inducing).to(self.Z) * 1e-6
#     124 )
#     125 eps = torch.randn(self.dim, self.num_inducing, batch_size).to(self.Z)
#     126 self.delta_Bz = torch.matmul(self.Lz, eps)
#
# _LinAlgError: linalg.cholesky: (Batch element 0): The factorization could not be completed because the input is not positive-definite (the leading minor of order 1 is not positive-definite).

# %%
weights = [param for param in model.net.parameters()]
weights
# Out:
# [Parameter containing:
#  tensor([[ 0.2522, -0.4199, -0.1787],
#          [    nan,     nan,     nan],
#          [    nan,     nan,     nan],
#          [ 0.4597, -0.0494, -0.2265],
#          [-0.0653, -0.2605,  0.0117],
#          [    nan,     nan,     nan],
#          [    nan,     nan,     nan],
#          [    nan,     nan,     nan],
#          [    nan,     nan,     nan],
#          [    nan,     nan,     nan]], requires_grad=True),
#  Parameter containing:
#  tensor([ 0.0483,     nan,     nan, -0.2740, -0.0216,     nan,     nan,     nan,
#              nan,     nan], requires_grad=True),
#  Parameter containing:
#  tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#          [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#          [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#          [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#          [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#          [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#          [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#          [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#          [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan],
#          [nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], requires_grad=True),
#  Parameter containing:
#  tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([nan], requires_grad=True)]

# %%
plot_loss(loss_graph, iter_graph)
#plot_loss(loss_graph[i-500:i-1], iter_graph[i-500:i-1])
mpl.pyplot.show()

# %%
model.drift_yt
# Out:
# tensor([[ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281],
#         [ 1.4281],
#         [-0.4281]])

# %%
def plot_h(hurst_fn, ts, y0, shift=0.0):
    """Plot Hurst function"""
    plt.figure(figsize=(5, 4))
    ht = []

    with torch.no_grad():
        for t, y in zip(ts, ys):
            ht.append(hurst_fn(t, y))
        ht = torch.tensor(ht)
        plt.plot(ts, ht, label=r"$h(t, X)$", alpha=0.8)
        plt.xlabel(r"$t$")
        plt.ylabel(r"$Hurst$")
        plt.legend()
def plot_true_h(ts, ht, shift=0.0):
    """Plot Hurst function"""
    """Plot Hurst function"""
    plt.figure(figsize=(5, 4))

    with torch.no_grad():

        plt.plot(ts - shift, ht, label="true h", alpha=0.8)
        plt.xlabel(r"$t$")
        plt.ylabel(r"$Hurst$")
        plt.legend()

# %%
plot_h(model.noise_path.compute_hurst, ts, ys)
mpl.pyplot.show()
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 plot_h(model.noise_path.compute_hurst, ts, ys)
#       2 mpl.pyplot.show()
#
# Cell In[14], line 8, in plot_h(hurst_fn, ts, y0, shift)
#       6 with torch.no_grad():
#       7     for t, y in zip(ts, ys):
# ----> 8         ht.append(hurst_fn(t, y))
#       9     ht = torch.tensor(ht)
#      10     plt.plot(ts, ht, label=r"$h(t, X)$", alpha=0.8)
#
# File ~/Downloads/controlled_fractional_noise/fractional_neural_sde/fractional_neural_sde/../fractional_neural_sde/fractional_noise.py:132, in SparseGPNoise.compute_hurst(self, t, ys)
#     130 t = t.view(-1, 1)
#     131 # time is converted into a positional encoding
# --> 132 out = self.driving_action(torch.cat([torch.sin(t), torch.cos(t), t, ys], dim=-1))
#     133 return out
#
# RuntimeError: Tensors must have same number of dimensions: got 2 and 1

# %%
plot_control(model, ts, ys)
mpl.pyplot.show()

# %%
plot_condition(model, ts, ys)
mpl.pyplot.show()

# %%
plot_true_h(ts, ht)
mpl.pyplot.show()

# %%
test = []
with torch.no_grad():
    count = 0
    for y in ys:
        t = ts[count]
        test.append(model.noise_path.driving_action(torch.tensor([torch.sin(t), torch.cos(t), t, y])))
        count = count + 1
    test = torch.tensor(test)
    plt.plot(ts, test, label=r"$h(t, X)$", alpha=0.8)
    plt.xlabel(r"$t$")
    plt.ylabel(r"$Hurst$")
    plt.legend()
    mpl.pyplot.show

# %%
# for visualization of drift
drift = []
with torch.no_grad():
    count = 0
    for t in ts:
        drift.append(model.net(torch.tensor([torch.sin(t), torch.cos(t), ys[0]])))
        count = count + 1
    drift = torch.tensor(drift)
    plt.plot(ts, drift, label=r"$h(t, X_t)$", alpha=0.8)
    plt.xlabel(r"$t$")
    plt.ylabel(r"$Drift$")
    plt.legend()
    mpl.pyplot.show

# %%
def plot_control(model, ts, y0, shift=0.0):
    """Plot Hurst function"""
    plt.figure(figsize=(5, 4))
    ht = []

    with torch.no_grad():
        for y in ys:
            ht.append(model.noise_path.condition_net(y))
        ht = torch.tensor(ht)
        plt.plot(ts, ht, label=r"$h(X)$", alpha=0.8)
        plt.xlabel(r"$t$")
        plt.ylabel(r"$Hurst$")
        plt.legend()
def plot_condition(model, ts, y0, shift=0.0):
    """Plot Hurst function"""
    plt.figure(figsize=(5, 4))
    ht = []

    with torch.no_grad():
        for t in ts:
            ht.append(model.noise_path.driving_action(torch.tensor([torch.sin(t), torch.cos(t), t])))
        ht = torch.tensor(ht)
        plt.plot(ts, ht, label=r"$h(t)$", alpha=0.8)
        plt.xlabel(r"$t$")
        plt.ylabel(r"$Hurst$")
        plt.legend()
# Out:
# [Parameter containing:
#  tensor([[nan, nan, nan, nan],
#          [nan, nan, nan, nan],
#          [nan, nan, nan, nan],
#          [nan, nan, nan, nan],
#          [nan, nan, nan, nan],
#          [nan, nan, nan, nan],
#          [nan, nan, nan, nan],
#          [nan, nan, nan, nan],
#          [nan, nan, nan, nan],
#          [nan, nan, nan, nan]], requires_grad=True),
#  Parameter containing:
#  tensor([nan, nan, nan, nan, nan, nan, nan, nan, nan, nan], requires_grad=True),
#  Parameter containing:
#  tensor([[nan, nan, nan, nan, nan, nan, nan, nan, nan, nan]],
#         requires_grad=True),
#  Parameter containing:
#  tensor([nan], requires_grad=True)]
