# %%
import torch
import torch.nn as nn
from torchsde import sdeint
import torchsde
import math
import random

# %%
# FIM SDE: this may be wrong. I'm not sure if the torch sde itegration works this way or not (the BM integral is kinda... weird.)
# ok I think I fixed it LOL
# I was calculating the power rule hurst on the wrong thing lmao...
class ItoMotion(nn.Module):
    noise_type = 'diagonal'
    sde_type = 'ito'

    def __init__(self, theta=1.0, mu=0.0, sigma=0.5, hurst = 0.5):
        super().__init__()
        self.register_buffer("theta", torch.tensor([[theta]]))
        self.register_buffer("mu", torch.tensor([[mu]]))
        self.register_buffer("sigma", torch.tensor([[sigma]]))
        log_var = math.log(sigma**2 / (2 * theta))
        self.IH_mean = nn.Parameter(torch.tensor([[mu]]), requires_grad=False)
        self.IH_logvar = nn.Parameter(torch.tensor([[log_var]]), requires_grad=False)
        self.hurst = 0
    @property    
    def std(self):
        return torch.exp(0.5 * self.IH_logvar) 
    @property
    def rand_neg(self):
        return 1 if random.random() < 0.5 else -1
    @torch.no_grad()
    def compute_hurst(self, t):
        return torch.ones(1, 1) * torch.sigmoid((1.0 - t) * 7.0) * 0.5 + 0.3

    def f(self, t, y):
        out = self.mu * y
        return out
    def BM(self, t, y):
        eps = torch.randn(batch_size, 1).to(self.IH_logvar)
        h = self.compute_hurst(t)
        I = self.std * eps
        I_H = torch.abs(I) ** (1 - 1/(2*h))
        dW = 
    def g(self, t, y):
        g = self.sigma.repeat(y.size(0), 1)
        return g
# Out:
#   Cell In[772], line 35
#     dW =
#          ^
# SyntaxError: invalid syntax

# %%
class SDE(torch.nn.Module):
    noise_type = 'diagonal'
    sde_type = 'ito'

    def __init__(self, hurst = 0.5, sigma = 0.5, dt = 0.005):
        super().__init__()
        self.mu = torch.nn.Linear(state_size, 
                                  state_size)
        self.noise_path = ItoMotion(hurst = hurst)
        self.register_buffer("sigma", torch.tensor([[sigma]]))
        self.x0 = 1
        self.beta = 0.5
        self.alpha = 0.5
        self.dt = dt

    # Drift
    def f(self, t, y):
        f = (y*self.alpha).repeat(1,1)
        return f  # shape (batch_size, state_size)

    # Diffusion
    def g(self, t, y):
        g = self.beta*torch.exp(torch.tensor([self.beta]))
        ito_motion = self.noise_path.g(t, y)
        return g

# %%
from fractional_noise_ import SparseGPNoise
class TrueNoise(SparseGPNoise):
    def compute_hurst(self, t):
        t = t.view(-1, 1)
        return torch.ones(1, 1) * torch.sigmoid((1.0 - t) * 7.0) * 0.5 + 0.3


def get_data():

    t0, t1 = 0.0, 2.0
    batch_size = 200

    x0 = 1.0
    alpha = 0.5
    beta = 0.5
    true_wn = TrueNoise(t0=t0, t1=t1, dt=1e-2, num_steps=500, num_inducings=50)

    true_wn.precompute(batch_size=batch_size)

    ts, B_h, _ = true_wn.sample_alternative(batch_size)

    ht = torch.stack(
        [true_wn.compute_hurst(t) for t in ts], dim=0
    )  # t_size, 1, state_size

    # the exact solution
    X_t = x0 * torch.exp(
        beta * B_h
        + alpha * ts.reshape(-1, 1, 1)
        - 0.5 * beta**2 * ts.reshape(-1, 1, 1) ** (2 * ht)
    )
    X_t = X_t.squeeze().transpose(0, 1)

    return ts, X_t[1], ht
ts, ys, ht = get_data()

# %%
batch_size, state_size, brownian_size = 1, 1, 1
t_size = 200
y0 = torch.full((batch_size, state_size), 1.)
# ts = torch.linspace(0, 2.0, t_size)
dt = ts[1] - ts[0]
bm = BrownianInterval(t0=ts[0], 
                      t1=ts[-1], 
                      size=(batch_size, brownian_size),
                      device='cpu')

# %%
torch.manual_seed(0)
ys_ito = []
ys_brownian = []
sde = SDE()
for p in sde.parameters():
    p.requires_grad = False
with torch.no_grad():
    for i in range(20):
        ys_ito.append(sdeint(sde, y0, ts))
        ys_brownian.append(get_data()[2])
# Out:
# torch.Size([200, 1, 1])
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[726], line 13
#      11 for i in range(20):
#      12     bm = sdeint(ito_motion, y0, ts).reshape(1, -1)
# ---> 13     ys_ito.append(sde(ts=ts, batch_size=batch_size, sdeint_fn=sdeint, dt=dt, bm = bm))
#      14     ys_brownian.append(get_data()[2])
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1518, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1516     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1517 else:
# -> 1518     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/lib/python3.10/site-packages/torch/nn/modules/module.py:1527, in Module._call_impl(self, *args, **kwargs)
#    1522 # If we don't have any hooks, we want to skip the rest of the logic in
#    1523 # this function, and just call forward.
# ...

# %%
#plt.figure()
#plt.plot(ts, sde.compute_hurst(ts).T)
#plt.show()
# Out:
# torch.Size([200, 1])

# %%
from matplotlib import pyplot as plt
plt.figure()
for i in range(20):
    #if i%2 == 0:
    plt.plot(ts, ys_ito[i].squeeze().detach(), color = "green") # h < .5
    plt.plot(ts, ys_brownian[i].squeeze().detach(), color = "red")
    #else:
    #    plt.plot(ts, ys[i].squeeze().detach(), color = "red") # h > .5
plt.xlabel('$t$')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[682], line 5
#       2 plt.figure()
#       3 for i in range(20):
#       4     #if i%2 == 0:
# ----> 5     plt.plot(ts, ys_ito[i].squeeze().detach(), color = "green") # h < .5
#       6     plt.plot(ts, ys_brownian[i].squeeze().detach(), color = "red")
#       7     #else:
#       8     #    plt.plot(ts, ys[i].squeeze().detach(), color = "red") # h > .5
#
# IndexError: list index out of range

# %%
# It now works
# after much pain
# the question now is
# do I rebuild the latent SDE model
# after trying to rebuild SDE, this broke

# %%
# testing loss intution
def sample(mean = 0, logvar = torch.tensor([1])):
    stdev = torch.exp(0.5 * logvar)
    var = torch.exp(logvar)
    eps = torch.randn(1, 1)
    sample  = eps * stdev
    return sample
def increment_variance(inc, h):
    var_1 = torch.exp(torch.tensor([1]))
    var_inc = (var_1 * ((5e-1) ** (2*h)))
    return var_inc
def hurst(t):
    if t > 1:
        return 0.3
    else:
        return 0.7

# %%
v_0 = torch.exp(torch.tensor([1]))
delta_t1 = sample() 
var_t1 = increment_variance(delta_t1, hurst(1))
delta_t2 = sample(logvar = torch.log(var_t1))
var_t2_1 = increment_variance(delta_t2, hurst(0))
var_t2_2 = var_t1 * ((5e-1) ** (2*hurst(0)))

# %%
v_0
# Out:
# tensor([2.7183])

# %%
var_t1
# Out:
# tensor([1.0300])

# %%
var_t2_1
# Out:
# tensor([1.0300])

# %%
var_t2_2
# Out:
# tensor([0.3903])

# %%
import jax.random as jrandom
from diffrax import diffeqsolve, ControlTerm, Euler, MultiTerm, ODETerm, SaveAt, VirtualBrownianTree

t0, t1 = 1, 3
drift = lambda t, y, args: -y
diffusion = lambda t, y, args: 0.1 * t
brownian_motion = VirtualBrownianTree(t0, t1, tol=1e-3, shape=(), key=jrandom.PRNGKey(0))
terms = MultiTerm(ODETerm(drift), ControlTerm(diffusion, brownian_motion))
solver = Euler()
saveat = SaveAt(dense=True)

sol = diffeqsolve(terms, solver, t0, t1, dt0=0.05, y0=1.0, saveat=saveat)
print(sol.evaluate(1.1))
# Out:
# 0.8960282

# %%
from diffrax import AbstractPath, ControlTerm, diffeqsolve, Dopri5


class QuadraticPath(AbstractPath):
    @property
    def t0(self):
        return 0

    @property
    def t1(self):
        return 3

    def evaluate(self, t0, t1=None, left=True):
        del left
        if t1 is not None:
            return self.evaluate(t1) - self.evaluate(t0)
        return t0 ** 2


vector_field = lambda t, y, args: -y
control = QuadraticPath()
term = ControlTerm(vector_field, control).to_ode()
solver = Dopri5()
sol = diffeqsolve(term, solver, t0=0, t1=3, dt0=0.05, y0=1)

print(sol.ts)  # DeviceArray([3.])
print(sol.ys)  # DeviceArray([0.00012341])
# Out:
# [3.]
# [0.00012341]

# %%
class GPFIMotion(nn.Module):
    noise_type = 'diagonal'
    sde_type = 'ito'

    def __init__(self, theta=1.0, mu=0.0, sigma=0.5, hurst = 0.5):
        super().__init__()
        self.register_buffer("theta", torch.tensor([[theta]]))
        self.register_buffer("mu", torch.tensor([[mu]]))
        self.register_buffer("sigma", torch.tensor([[sigma]]))
        log_var = math.log(sigma**2 / (2 * theta))
        self.IH_mean = nn.Parameter(torch.tensor([[mu]]), requires_grad=False)
        self.IH_logvar = nn.Parameter(torch.tensor([[log_var]]), requires_grad=False)
        eps = torch.randn(batch_size, 1).to(self.IH_logvar)
        self.sample = nn.Parameter(self.std * eps - 1, requires_grad = False)
        self.hurst = hurst
        self.count = 1
    @property    
    def std(self):
        return torch.exp(0.5 * self.IH_logvar) 
    @property
    def rand_neg(self):
        return 1 if random.random() < 0.5 else -1
    @torch.no_grad()
    def compute_hurst(self, t):
        if t > 1.0:
            hurst = torch.tensor([0.9])
        else:
            hurst = torch.tensor([0.3])
        self.count = self.count + 1
        return hurst
    def resample():
        eps = torch.randn(batch_size, 1).to(self.IH_logvar)
        self.sample = nn.Parameter(self.std * eps, requires_grad = False)
    def f(self, t, y):
        out = 0 * y
        return out
    def g(self, t, y):
        h = self.compute_hurst(t)
        I = self.sample
        I_H = torch.abs(I) ** (1 - 1/(2*h))
        return I_H.repeat(y.size(0), 1)
    def forward(self, y0, ts):
        self.resample()
        return sdeint(self, y0, ts)

# %%
torch.manual_seed(0)
ys = []
ts = torch.linspace(0, 2.0, 200)
y0 = torch.full((batch_size, state_size), 0.)
sub_sde = GPFIMotion(hurst = 0.3)
sup_sde = GPFIMotion(hurst = 0.7)
for p in sde.parameters():
    p.requires_grad = False
with torch.no_grad():
    for i in range(20):
        #if i%2 == 0:
        ys.append(sdeint(sub_sde, y0, ts))
        #else:
        #    ys.append(sdeint(sup_sde, y0, ts))

# %%
from matplotlib import pyplot as plt
plt.figure()
for i in range(20):
    if i%2 == 0:
        plt.plot(ts, ys[i].squeeze().detach(), color = "green") # h < .5
    else:
        plt.plot(ts, ys[i].squeeze().detach(), color = "green") # h > .5
plt.xlabel('$t$')
plt.show()
